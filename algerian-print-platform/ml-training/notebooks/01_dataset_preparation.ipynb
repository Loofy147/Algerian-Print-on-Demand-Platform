# %% [markdown]
# # Algerian Print-on-Demand: 01 - Dataset Preparation
#
# This notebook handles the cleaning, resizing, and captioning of our raw image dataset.

# %%
import os
from PIL import Image
import torch
from transformers import BlipProcessor, BlipForConditionalGeneration
from tqdm.auto import tqdm

print(f'PyTorch version: {torch.__version__}')

# %% [markdown]
# ## Configuration

# %%
RAW_DATA_DIR = '/kaggle/input/algerian-print-dataset-raw/'
PROCESSED_DATA_DIR = '/kaggle/working/algerian-print-dataset-processed/'
IMAGE_SIZE = 1024

# %% [markdown]
# ## Step 1: Image Resizing and Cleaning

# %%
def resize_and_clean_images():
    # To be implemented
    pass

# %% [markdown]
# ## Step 2: Image Captioning

# %%
def generate_captions():
    # To be implemented
    pass
